# %%
print("to jest notebook")
# Out:
# to jest notebook

# %%
a = 101
b = 353
c = 0.464

# %%
wynik = (a+b)*c
wynik
#ipython
# Out:
# 210.656

# %%
(wynik - 11)*2
# Out:
# 399.312

# %% [markdown]
# to  jest mój testowy **notebook** (<span style="color:red; font-size:15pt;">jupyter</span>)
